# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import sys

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_long = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-100.000, high=100.000, size=1500)
longs = np.random.uniform(low=-200.000, high=200.000, size=1500)
lat_longs = zip(lats, longs)

# Identify nearest city for each lat, lng combination
for lat_long in lat_longs:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 514

# %%
# get_key = api_keys.get_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city  = []
cloudy = []
cntry = []
dte = []
humidity = []
lat = []
long = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city.get('name', default=None)
        print(city)
        city.get('dt', default=None)
        
        
        print(f"Processing Record {record} | {city}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("Oops!",sys.exc_info()[0],"occured.")
        # print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# lakatoroLakatoro
# Processing Record 1 | lakatoroLakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lakatoroLakatoro
# oronOron
# Processing Record 2 | oronOron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=oronOron
# ushuaiaUshuaia
# Processing Record 3 | ushuaiaUshuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ushuaiaUshuaia
# olindaOlinda
# Processing Record 4 | olindaOlinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=olindaOlinda
# sao joao da barraSao Joao da Barra
# Processing Record 5 | sao joao da barraSao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sao joao da barraSao Joao da Barra
# nikolskoyeNikolskoye
# Processing Record 6 | nikolskoyeNikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nikolskoyeNikolskoye
# Oops! <class 'KeyError'> occured.
# severo-kurilskSevero-Kurilsk
# Processing Record 7 | severo-kurilskSevero-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=severo-kurilskSevero-Kurilsk
# granadilla de abonaGranadilla de Abona
# Processing Record 8 | granadilla de abonaGranadilla de Abona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=granadilla de abonaGranadilla de Abona
# punta arenasPunta Arenas
# Processing Record 9 | punta arenasPunta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=punta arenasPunta Arenas
# sitkaSitka
# Processing Record 10 | sitkaSitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sitkaSitka
# Oops! <class 'KeyError'> occured.
# Oops! <class 'KeyError'> occured.
# jamestownJamestown
# Processing Record 11 | jamestownJamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jamestownJamestown
# turaTura
# Processing Record 12 | turaTura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=turaTura
# souillacSouillac
# Processing Record 13 | souillacSouillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=souillacSouillac
# westportWestport
# Processing Record 14 | westportWestport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=westportWestport
# atuonaAtuona
# Processing Record 15 | atuonaAtuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=atuonaAtuona
# matauraMataura
# Processing Record 16 | matauraMataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=matauraMataura
# albanyAlbany
# Processing Record 17 | albanyAlbany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=albanyAlbany
# paysonPayson
# Processing Record 18 | paysonPayson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=paysonPayson
# kununurraKununurra
# Processing Record 19 | kununurraKununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kununurraKununurra
# vainiVaini
# Processing Record 20 | vainiVaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vainiVaini
# rikiteaRikitea
# Processing Record 21 | rikiteaRikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rikiteaRikitea
# soeSoe
# Processing Record 22 | soeSoe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=soeSoe
# puerto escondidoPuerto Escondido
# Processing Record 23 | puerto escondidoPuerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=puerto escondidoPuerto Escondido
# sainte-anne-des-montsSainte-Anne-des-Monts
# Processing Record 24 | sainte-anne-des-montsSainte-Anne-des-Monts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sainte-anne-des-montsSainte-Anne-des-Monts
# komsomolskiyKomsomolskiy
# Processing Record 25 | komsomolskiyKomsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=komsomolskiyKomsomolskiy
# east londonEast London
# Processing Record 26 | east londonEast London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=east londonEast London
# bambous virieuxBambous Virieux
# Processing Record 27 | bambous virieuxBambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bambous virieuxBambous Virieux
# shetpeShetpe
# Processing Record 28 | shetpeShetpe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=shetpeShetpe
# gayaGaya
# Processing Record 29 | gayaGaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gayaGaya
# carnarvonCarnarvon
# Processing Record 30 | carnarvonCarnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=carnarvonCarnarvon
# kodiakKodiak
# Processing Record 31 | kodiakKodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kodiakKodiak
# Oops! <class 'KeyError'> occured.
# Oops! <class 'KeyError'> occured.
# nemuroNemuro
# Processing Record 32 | nemuroNemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nemuroNemuro
# cidreiraCidreira
# Processing Record 33 | cidreiraCidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cidreiraCidreira
# tiksiTiksi
# Processing Record 34 | tiksiTiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tiksiTiksi
# Oops! <class 'KeyError'> occured.
# linxiaLinxia
# Processing Record 35 | linxiaLinxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=linxiaLinxia
# egvekinotEgvekinot
# Processing Record 36 | egvekinotEgvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=egvekinotEgvekinot
# vaoVao
# Processing Record 37 | vaoVao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vaoVao
# hobartHobart
# Processing Record 38 | hobartHobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hobartHobart
# the pasThe Pas
# Processing Record 39 | the pasThe Pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=the pasThe Pas
# san patricioSan Patricio
# Processing Record 40 | san patricioSan Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san patricioSan Patricio
# geraldtonGeraldton
# Processing Record 41 | geraldtonGeraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=geraldtonGeraldton
# saint-philippeSaint-Philippe
# Processing Record 42 | saint-philippeSaint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint-philippeSaint-Philippe
# castroCastro
# Processing Record 43 | castroCastro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=castroCastro
# faanuiFaanui
# Processing Record 44 | faanuiFaanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=faanuiFaanui
# Oops! <class 'KeyError'> occured.
# busseltonBusselton
# Processing Record 45 | busseltonBusselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=busseltonBusselton
# loa jananLoa Janan
# Processing Record 46 | loa jananLoa Janan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=loa jananLoa Janan
# xichangXichang
# Processing Record 47 | xichangXichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=xichangXichang
# saint anthonySaint Anthony
# Processing Record 48 | saint anthonySaint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint anthonySaint Anthony
# upernavikUpernavik
# Processing Record 49 | upernavikUpernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=upernavikUpernavik
# port alfredPort Alfred
# Processing Record 50 | port alfredPort Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port alfredPort Alfred
# ilulissatIlulissat
# Processing Record 51 | ilulissatIlulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ilulissatIlulissat
# Oops! <class 'KeyError'> occured.
# chokurdakhChokurdakh
# Processing Record 52 | chokurdakhChokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chokurdakhChokurdakh
# talnakhTalnakh
# Processing Record 53 | talnakhTalnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=talnakhTalnakh
# digDig
# Processing Record 54 | digDig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=digDig
# beringovskiyBeringovskiy
# Processing Record 55 | beringovskiyBeringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=beringovskiyBeringovskiy
# Oops! <class 'KeyError'> occured.
# hermanusHermanus
# Processing Record 56 | hermanusHermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hermanusHermanus
# avaruaAvarua
# Processing Record 57 | avaruaAvarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=avaruaAvarua
# kietaKieta
# Processing Record 58 | kietaKieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kietaKieta
# arraial do caboArraial do Cabo
# Processing Record 59 | arraial do caboArraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=arraial do caboArraial do Cabo
# diksonDikson
# Processing Record 60 | diksonDikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=diksonDikson
# lompocLompoc
# Processing Record 61 | lompocLompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lompocLompoc
# byron bayByron Bay
# Processing Record 62 | byron bayByron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=byron bayByron Bay
# waipawaWaipawa
# Processing Record 63 | waipawaWaipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=waipawaWaipawa
# santa isabel do rio negroSanta Isabel do Rio Negro
# Processing Record 64 | santa isabel do rio negroSanta Isabel do Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=santa isabel do rio negroSanta Isabel do Rio Negro
# brazzavilleBrazzaville
# Processing Record 65 | brazzavilleBrazzaville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=brazzavilleBrazzaville
# yellowknifeYellowknife
# Processing Record 66 | yellowknifeYellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yellowknifeYellowknife
# caluquembeCaluquembe
# Processing Record 67 | caluquembeCaluquembe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=caluquembeCaluquembe
# pevekPevek
# Processing Record 68 | pevekPevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pevekPevek
# kidalKidal
# Processing Record 69 | kidalKidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kidalKidal
# tasiilaqTasiilaq
# Processing Record 70 | tasiilaqTasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tasiilaqTasiilaq
# forestvilleForestville
# Processing Record 71 | forestvilleForestville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=forestvilleForestville
# Oops! <class 'KeyError'> occured.
# Oops! <class 'KeyError'> occured.
# kaitangataKaitangata
# Processing Record 72 | kaitangataKaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kaitangataKaitangata
# Oops! <class 'KeyError'> occured.
# husavikHusavik
# Processing Record 73 | husavikHusavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=husavikHusavik
# coroicoCoroico
# Processing Record 74 | coroicoCoroico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=coroicoCoroico
# Oops! <class 'KeyError'> occured.
# georgetownGeorgetown
# Processing Record 75 | georgetownGeorgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=georgetownGeorgetown
# kapaaKapaa
# Processing Record 76 | kapaaKapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kapaaKapaa
# tuktoyaktukTuktoyaktuk
# Processing Record 77 | tuktoyaktukTuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tuktoyaktukTuktoyaktuk
# karatonKaraton
# Processing Record 78 | karatonKaraton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=karatonKaraton
# mount gambierMount Gambier
# Processing Record 79 | mount gambierMount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mount gambierMount Gambier
# mahebourgMahebourg
# Processing Record 80 | mahebourgMahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mahebourgMahebourg
# Oops! <class 'KeyError'> occured.
# russellRussell
# Processing Record 81 | russellRussell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=russellRussell
# hohhotHohhot
# Processing Record 82 | hohhotHohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hohhotHohhot
# Oops! <class 'KeyError'> occured.
# tolaga bayTolaga Bay
# Processing Record 83 | tolaga bayTolaga Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tolaga bayTolaga Bay
# new norfolkNew Norfolk
# Processing Record 84 | new norfolkNew Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=new norfolkNew Norfolk
# russkaya polyanaRusskaya Polyana
# Processing Record 85 | russkaya polyanaRusskaya Polyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=russkaya polyanaRusskaya Polyana
# leningradskiyLeningradskiy
# Processing Record 86 | leningradskiyLeningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=leningradskiyLeningradskiy
# dunedinDunedin
# Processing Record 87 | dunedinDunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dunedinDunedin
# palm coastPalm Coast
# Processing Record 88 | palm coastPalm Coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=palm coastPalm Coast
# kungurtugKungurtug
# Processing Record 89 | kungurtugKungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kungurtugKungurtug
# inuvikInuvik
# Processing Record 90 | inuvikInuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=inuvikInuvik
# longyearbyenLongyearbyen
# Processing Record 91 | longyearbyenLongyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=longyearbyenLongyearbyen
# wahiawaWahiawa
# Processing Record 92 | wahiawaWahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=wahiawaWahiawa
# galesongGalesong
# Processing Record 93 | galesongGalesong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=galesongGalesong
# thompsonThompson
# Processing Record 94 | thompsonThompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=thompsonThompson
# lagoaLagoa
# Processing Record 95 | lagoaLagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lagoaLagoa
# ribeira grandeRibeira Grande
# Processing Record 96 | ribeira grandeRibeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ribeira grandeRibeira Grande
# Oops! <class 'KeyError'> occured.
# cherskiyCherskiy
# Processing Record 97 | cherskiyCherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cherskiyCherskiy
# nuevo progresoNuevo Progreso
# Processing Record 98 | nuevo progresoNuevo Progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nuevo progresoNuevo Progreso
# Oops! <class 'KeyError'> occured.
# Oops! <class 'KeyError'> occured.
# saskylakhSaskylakh
# Processing Record 99 | saskylakhSaskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saskylakhSaskylakh
# hovdHovd
# Processing Record 100 | hovdHovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hovdHovd
# sikongeSikonge
# Processing Record 101 | sikongeSikonge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sikongeSikonge
# fortunaFortuna
# Processing Record 102 | fortunaFortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fortunaFortuna
# Oops! <class 'KeyError'> occured.
# barahonaBarahona
# Processing Record 103 | barahonaBarahona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=barahonaBarahona
# morondavaMorondava
# Processing Record 104 | morondavaMorondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=morondavaMorondava
# cape townCape Town
# Processing Record 105 | cape townCape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cape townCape Town
# zhiganskZhigansk
# Processing Record 106 | zhiganskZhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=zhiganskZhigansk
# jaluJalu
# Processing Record 107 | jaluJalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jaluJalu
# guerrero negroGuerrero Negro
# Processing Record 108 | guerrero negroGuerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=guerrero negroGuerrero Negro
# anadyrAnadyr
# Processing Record 109 | anadyrAnadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=anadyrAnadyr
# Oops! <class 'KeyError'> occured.
# saint stephenSaint Stephen
# Processing Record 110 | saint stephenSaint Stephen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint stephenSaint Stephen
# san luisSan Luis
# Processing Record 111 | san luisSan Luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san luisSan Luis
# yar-saleYar-Sale
# Processing Record 112 | yar-saleYar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yar-saleYar-Sale
# qaanaaqQaanaaq
# Processing Record 113 | qaanaaqQaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=qaanaaqQaanaaq
# yarmouthYarmouth
# Processing Record 114 | yarmouthYarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yarmouthYarmouth
# pamanukanPamanukan
# Processing Record 115 | pamanukanPamanukan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pamanukanPamanukan
# iqaluitIqaluit
# Processing Record 116 | iqaluitIqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=iqaluitIqaluit
# Oops! <class 'KeyError'> occured.
# bad ausseeBad Aussee
# Processing Record 117 | bad ausseeBad Aussee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bad ausseeBad Aussee
# ghanziGhanzi
# Processing Record 118 | ghanziGhanzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ghanziGhanzi
# bluffBluff
# Processing Record 119 | bluffBluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bluffBluff
# oussouyeOussouye
# Processing Record 120 | oussouyeOussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=oussouyeOussouye
# Oops! <class 'KeyError'> occured.
# petropavlovsk-kamchatskiyPetropavlovsk-Kamchatskiy
# Processing Record 121 | petropavlovsk-kamchatskiyPetropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=petropavlovsk-kamchatskiyPetropavlovsk-Kamchatskiy
# tabukTabuk
# Processing Record 122 | tabukTabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tabukTabuk
# riberaltaRiberalta
# Processing Record 123 | riberaltaRiberalta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=riberaltaRiberalta
# saint georgeSaint George
# Processing Record 124 | saint georgeSaint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint georgeSaint George
# narsaqNarsaq
# Processing Record 125 | narsaqNarsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=narsaqNarsaq
# puerto madrynPuerto Madryn
# Processing Record 126 | puerto madrynPuerto Madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=puerto madrynPuerto Madryn
# mar del plataMar del Plata
# Processing Record 127 | mar del plataMar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mar del plataMar del Plata
# manganMangan
# Processing Record 128 | manganMangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=manganMangan
# melakaMelaka
# Processing Record 129 | melakaMelaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=melakaMelaka
# mandalgoviMandalgovi
# Processing Record 130 | mandalgoviMandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mandalgoviMandalgovi
# mount isaMount Isa
# Processing Record 131 | mount isaMount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mount isaMount Isa
# Oops! <class 'KeyError'> occured.
# evenskEvensk
# Processing Record 132 | evenskEvensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=evenskEvensk
# khatangaKhatanga
# Processing Record 133 | khatangaKhatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=khatangaKhatanga
# yashkinoYashkino
# Processing Record 134 | yashkinoYashkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yashkinoYashkino
# beatriceBeatrice
# Processing Record 135 | beatriceBeatrice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=beatriceBeatrice
# Oops! <class 'KeyError'> occured.
# san cristobalSan Cristobal
# Processing Record 136 | san cristobalSan Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san cristobalSan Cristobal
# nortelandiaNortelandia
# Processing Record 137 | nortelandiaNortelandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nortelandiaNortelandia
# yantalYantal
# Processing Record 138 | yantalYantal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yantalYantal
# kavarattiKavaratti
# Processing Record 139 | kavarattiKavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kavarattiKavaratti
# minabMinab
# Processing Record 140 | minabMinab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=minabMinab
# natalNatal
# Processing Record 141 | natalNatal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=natalNatal
# san jeronimoSan Jeronimo
# Processing Record 142 | san jeronimoSan Jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san jeronimoSan Jeronimo
# salinopolisSalinopolis
# Processing Record 143 | salinopolisSalinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=salinopolisSalinopolis
# richards bayRichards Bay
# Processing Record 144 | richards bayRichards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=richards bayRichards Bay
# pau brasilPau Brasil
# Processing Record 145 | pau brasilPau Brasil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pau brasilPau Brasil
# margateMargate
# Processing Record 146 | margateMargate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=margateMargate
# barrowBarrow
# Processing Record 147 | barrowBarrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=barrowBarrow
# sioux lookoutSioux Lookout
# Processing Record 148 | sioux lookoutSioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sioux lookoutSioux Lookout
# sonkovoSonkovo
# Processing Record 149 | sonkovoSonkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sonkovoSonkovo
# kiamaKiama
# Processing Record 150 | kiamaKiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kiamaKiama
# Oops! <class 'KeyError'> occured.
# tervelTervel
# Processing Record 151 | tervelTervel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tervelTervel
# Oops! <class 'KeyError'> occured.
# hare bayHare Bay
# Processing Record 152 | hare bayHare Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hare bayHare Bay
# victoriaVictoria
# Processing Record 153 | victoriaVictoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=victoriaVictoria
# nomeNome
# Processing Record 154 | nomeNome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nomeNome
# sorlandSorland
# Processing Record 155 | sorlandSorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sorlandSorland
# alice springsAlice Springs
# Processing Record 156 | alice springsAlice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=alice springsAlice Springs
# Oops! <class 'KeyError'> occured.
# provideniyaProvideniya
# Processing Record 157 | provideniyaProvideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=provideniyaProvideniya
# grand gaubeGrand Gaube
# Processing Record 158 | grand gaubeGrand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=grand gaubeGrand Gaube
# braeBrae
# Processing Record 159 | braeBrae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=braeBrae
# boyolanguBoyolangu
# Processing Record 160 | boyolanguBoyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=boyolanguBoyolangu
# Oops! <class 'KeyError'> occured.
# owensboroOwensboro
# Processing Record 161 | owensboroOwensboro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=owensboroOwensboro
# katsuuraKatsuura
# Processing Record 162 | katsuuraKatsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=katsuuraKatsuura
# vanimoVanimo
# Processing Record 163 | vanimoVanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vanimoVanimo
# the valleyThe Valley
# Processing Record 164 | the valleyThe Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=the valleyThe Valley
# airaiAirai
# Processing Record 165 | airaiAirai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=airaiAirai
# port moresbyPort Moresby
# Processing Record 166 | port moresbyPort Moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port moresbyPort Moresby
# truckeeTruckee
# Processing Record 167 | truckeeTruckee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=truckeeTruckee
# vytegraVytegra
# Processing Record 168 | vytegraVytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vytegraVytegra
# ulladullaUlladulla
# Processing Record 169 | ulladullaUlladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ulladullaUlladulla
# Oops! <class 'KeyError'> occured.
# hiloHilo
# Processing Record 170 | hiloHilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hiloHilo
# Oops! <class 'KeyError'> occured.
# riyadhRiyadh
# Processing Record 171 | riyadhRiyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=riyadhRiyadh
# sao filipeSao Filipe
# Processing Record 172 | sao filipeSao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sao filipeSao Filipe
# umm lajjUmm Lajj
# Processing Record 173 | umm lajjUmm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=umm lajjUmm Lajj
# isla mujeresIsla Mujeres
# Processing Record 174 | isla mujeresIsla Mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=isla mujeresIsla Mujeres
# Oops! <class 'KeyError'> occured.
# esperanceEsperance
# Processing Record 175 | esperanceEsperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=esperanceEsperance
# berlevagBerlevag
# Processing Record 176 | berlevagBerlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=berlevagBerlevag
# port elizabethPort Elizabeth
# Processing Record 177 | port elizabethPort Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port elizabethPort Elizabeth
# quatre cocosQuatre Cocos
# Processing Record 178 | quatre cocosQuatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=quatre cocosQuatre Cocos
# hokitikaHokitika
# Processing Record 179 | hokitikaHokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hokitikaHokitika
# greenwoodGreenwood
# Processing Record 180 | greenwoodGreenwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=greenwoodGreenwood
# lakes entranceLakes Entrance
# Processing Record 181 | lakes entranceLakes Entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lakes entranceLakes Entrance
# athertonAtherton
# Processing Record 182 | athertonAtherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=athertonAtherton
# severo-yeniseyskiySevero-Yeniseyskiy
# Processing Record 183 | severo-yeniseyskiySevero-Yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=severo-yeniseyskiySevero-Yeniseyskiy
# koiduKoidu
# Processing Record 184 | koiduKoidu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=koiduKoidu
# bongaBonga
# Processing Record 185 | bongaBonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bongaBonga
# portlandPortland
# Processing Record 186 | portlandPortland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=portlandPortland
# itomanItoman
# Processing Record 187 | itomanItoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=itomanItoman
# beruwalaBeruwala
# Processing Record 188 | beruwalaBeruwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=beruwalaBeruwala
# presidencia roque saenz penaPresidencia Roque Saenz Pena
# Processing Record 189 | presidencia roque saenz penaPresidencia Roque Saenz Pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=presidencia roque saenz penaPresidencia Roque Saenz Pena
# lasaLasa
# Processing Record 190 | lasaLasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lasaLasa
# beidaoBeidao
# Processing Record 191 | beidaoBeidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=beidaoBeidao
# khasanKhasan
# Processing Record 192 | khasanKhasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=khasanKhasan
# ancudAncud
# Processing Record 193 | ancudAncud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ancudAncud
# norman wellsNorman Wells
# Processing Record 194 | norman wellsNorman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=norman wellsNorman Wells
# mahanoroMahanoro
# Processing Record 195 | mahanoroMahanoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mahanoroMahanoro
# olbiaOlbia
# Processing Record 196 | olbiaOlbia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=olbiaOlbia
# torataTorata
# Processing Record 197 | torataTorata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=torataTorata
# susanvilleSusanville
# Processing Record 198 | susanvilleSusanville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=susanvilleSusanville
# arlitArlit
# Processing Record 199 | arlitArlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=arlitArlit
# vostokVostok
# Processing Record 200 | vostokVostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vostokVostok
# romaRome
# Processing Record 201 | romaRome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=romaRome
# Oops! <class 'KeyError'> occured.
# lac du bonnetLac du Bonnet
# Processing Record 202 | lac du bonnetLac du Bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lac du bonnetLac du Bonnet
# sao miguel do araguaiaSao Miguel do Araguaia
# Processing Record 203 | sao miguel do araguaiaSao Miguel do Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sao miguel do araguaiaSao Miguel do Araguaia
# xudatKhudat
# Processing Record 204 | xudatKhudat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=xudatKhudat
# sambavaSambava
# Processing Record 205 | sambavaSambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sambavaSambava
# iskateleyIskateley
# Processing Record 206 | iskateleyIskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=iskateleyIskateley
# oranjestadOranjestad
# Processing Record 207 | oranjestadOranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=oranjestadOranjestad
# marawiMarawi
# Processing Record 208 | marawiMarawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=marawiMarawi
# noumeaNoumea
# Processing Record 209 | noumeaNoumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=noumeaNoumea
# butaritariButaritari
# Processing Record 210 | butaritariButaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=butaritariButaritari
# baftBaft
# Processing Record 211 | baftBaft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=baftBaft
# laurinburgLaurinburg
# Processing Record 212 | laurinburgLaurinburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=laurinburgLaurinburg
# mozarlandiaMozarlandia
# Processing Record 213 | mozarlandiaMozarlandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mozarlandiaMozarlandia
# Oops! <class 'KeyError'> occured.
# biakBiak
# Processing Record 214 | biakBiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=biakBiak
# sterlingSterling
# Processing Record 215 | sterlingSterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sterlingSterling
# campbell riverCampbell River
# Processing Record 216 | campbell riverCampbell River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=campbell riverCampbell River
# santo antonio de posseSanto Antonio de Posse
# Processing Record 217 | santo antonio de posseSanto Antonio de Posse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=santo antonio de posseSanto Antonio de Posse
# kaputaKaputa
# Processing Record 218 | kaputaKaputa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kaputaKaputa
# oyamaOyama
# Processing Record 219 | oyamaOyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=oyamaOyama
# bethelBethel
# Processing Record 220 | bethelBethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bethelBethel
# itaremaItarema
# Processing Record 221 | itaremaItarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=itaremaItarema
# illapelIllapel
# Processing Record 222 | illapelIllapel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=illapelIllapel
# anchorageAnchorage
# Processing Record 223 | anchorageAnchorage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=anchorageAnchorage
# klaksvikKlaksvik
# Processing Record 224 | klaksvikKlaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=klaksvikKlaksvik
# sinnamarySinnamary
# Processing Record 225 | sinnamarySinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sinnamarySinnamary
# hobyoHobyo
# Processing Record 226 | hobyoHobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hobyoHobyo
# bathshebaBathsheba
# Processing Record 227 | bathshebaBathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bathshebaBathsheba
# tuatapereTuatapere
# Processing Record 228 | tuatapereTuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tuatapereTuatapere
# ostrovnoyOstrovnoy
# Processing Record 229 | ostrovnoyOstrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ostrovnoyOstrovnoy
# wanningWanning
# Processing Record 230 | wanningWanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=wanningWanning
# naviraiNavirai
# Processing Record 231 | naviraiNavirai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=naviraiNavirai
# filingueFilingue
# Processing Record 232 | filingueFilingue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=filingueFilingue
# kruisfonteinKruisfontein
# Processing Record 233 | kruisfonteinKruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kruisfonteinKruisfontein
# la rongeLa Ronge
# Processing Record 234 | la rongeLa Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=la rongeLa Ronge
# Oops! <class 'KeyError'> occured.
# Oops! <class 'KeyError'> occured.
# moeraiMoerai
# Processing Record 235 | moeraiMoerai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=moeraiMoerai
# toora-khemToora-Khem
# Processing Record 236 | toora-khemToora-Khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=toora-khemToora-Khem
# agadezAgadez
# Processing Record 237 | agadezAgadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=agadezAgadez
# zhangyeZhangye
# Processing Record 238 | zhangyeZhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=zhangyeZhangye
# boddamBoddam
# Processing Record 239 | boddamBoddam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=boddamBoddam
# kamiisoKamiiso
# Processing Record 240 | kamiisoKamiiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kamiisoKamiiso
# lebuLebu
# Processing Record 241 | lebuLebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lebuLebu
# winnemuccaWinnemucca
# Processing Record 242 | winnemuccaWinnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=winnemuccaWinnemucca
# seoulSeoul
# Processing Record 243 | seoulSeoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=seoulSeoul
# puerto ayoraPuerto Ayora
# Processing Record 244 | puerto ayoraPuerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=puerto ayoraPuerto Ayora
# kahuluiKahului
# Processing Record 245 | kahuluiKahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kahuluiKahului
# alofiAlofi
# Processing Record 246 | alofiAlofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=alofiAlofi
# ahiparaAhipara
# Processing Record 247 | ahiparaAhipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ahiparaAhipara
# lataLata
# Processing Record 248 | lataLata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lataLata
# akureyriAkureyri
# Processing Record 249 | akureyriAkureyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=akureyriAkureyri
# port-gentilPort-Gentil
# Processing Record 250 | port-gentilPort-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port-gentilPort-Gentil
# eastbourneEastbourne
# Processing Record 251 | eastbourneEastbourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=eastbourneEastbourne
# bredasdorpBredasdorp
# Processing Record 252 | bredasdorpBredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bredasdorpBredasdorp
# krapkowiceKrapkowice
# Processing Record 253 | krapkowiceKrapkowice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=krapkowiceKrapkowice
# kattivakkamKattivakkam
# Processing Record 254 | kattivakkamKattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kattivakkamKattivakkam
# kirksvilleKirksville
# Processing Record 255 | kirksvilleKirksville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kirksvilleKirksville
# necocheaNecochea
# Processing Record 256 | necocheaNecochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=necocheaNecochea
# vredenVreden
# Processing Record 257 | vredenVreden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vredenVreden
# bethuneBethune
# Processing Record 258 | bethuneBethune
# ...
# atambuaAtambua
# Processing Record 301 | atambuaAtambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=atambuaAtambua
# yangambiYangambi
# Processing Record 302 | yangambiYangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yangambiYangambi
# ust-mayaUst-Maya
# Processing Record 303 | ust-mayaUst-Maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ust-mayaUst-Maya
# matamorosMatamoros
# Processing Record 304 | matamorosMatamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=matamorosMatamoros
# srednekolymskSrednekolymsk
# Processing Record 305 | srednekolymskSrednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=srednekolymskSrednekolymsk
# gazanjykGazanjyk
# Processing Record 306 | gazanjykGazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gazanjykGazanjyk
# Oops! <class 'KeyError'> occured.
# singarajaSingaraja
# Processing Record 307 | singarajaSingaraja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=singarajaSingaraja
# dakarDakar
# Processing Record 308 | dakarDakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dakarDakar
# canavieirasCanavieiras
# Processing Record 309 | canavieirasCanavieiras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=canavieirasCanavieiras
# clyde riverClyde River
# Processing Record 310 | clyde riverClyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=clyde riverClyde River
# saint-pierreSaint-Pierre
# Processing Record 311 | saint-pierreSaint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint-pierreSaint-Pierre
# parkesParkes
# Processing Record 312 | parkesParkes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=parkesParkes
# ketchikanKetchikan
# Processing Record 313 | ketchikanKetchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ketchikanKetchikan
# coffs harbourCoffs Harbour
# Processing Record 314 | coffs harbourCoffs Harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=coffs harbourCoffs Harbour
# salisteSaliste
# Processing Record 315 | salisteSaliste
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=salisteSaliste
# aykhalAykhal
# Processing Record 316 | aykhalAykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=aykhalAykhal
# harperHarper
# Processing Record 317 | harperHarper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=harperHarper
# haileyHailey
# Processing Record 318 | haileyHailey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=haileyHailey
# luwukLuwuk
# Processing Record 319 | luwukLuwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=luwukLuwuk
# salzwedelSalzwedel
# Processing Record 320 | salzwedelSalzwedel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=salzwedelSalzwedel
# ouaddaOuadda
# Processing Record 321 | ouaddaOuadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ouaddaOuadda
# okahandjaOkahandja
# Processing Record 322 | okahandjaOkahandja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=okahandjaOkahandja
# wagarWagar
# Processing Record 323 | wagarWagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=wagarWagar
# tsarychankaTsarychanka
# Processing Record 324 | tsarychankaTsarychanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tsarychankaTsarychanka
# Oops! <class 'KeyError'> occured.
# san vicenteSan Vicente
# Processing Record 325 | san vicenteSan Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san vicenteSan Vicente
# katherineKatherine
# Processing Record 326 | katherineKatherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=katherineKatherine
# Oops! <class 'KeyError'> occured.
# santa rosaliaSanta Rosalia
# Processing Record 327 | santa rosaliaSanta Rosalia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=santa rosaliaSanta Rosalia
# broomeBroome
# Processing Record 328 | broomeBroome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=broomeBroome
# sovetskaya gavanSovetskaya Gavan
# Processing Record 329 | sovetskaya gavanSovetskaya Gavan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sovetskaya gavanSovetskaya Gavan
# bebaBeba
# Processing Record 330 | bebaBeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bebaBeba
# Oops! <class 'KeyError'> occured.
# cervoCervo
# Processing Record 331 | cervoCervo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cervoCervo
# scarboroughScarborough
# Processing Record 332 | scarboroughScarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=scarboroughScarborough
# palmerPalmer
# Processing Record 333 | palmerPalmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=palmerPalmer
# schwerteSchwerte
# Processing Record 334 | schwerteSchwerte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=schwerteSchwerte
# bambanglipuroBambanglipuro
# Processing Record 335 | bambanglipuroBambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bambanglipuroBambanglipuro
# abu zabadAbu Zabad
# Processing Record 336 | abu zabadAbu Zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=abu zabadAbu Zabad
# sitgesSitges
# Processing Record 337 | sitgesSitges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sitgesSitges
# ishigakiIshigaki
# Processing Record 338 | ishigakiIshigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ishigakiIshigaki
# port augustaPort Augusta
# Processing Record 339 | port augustaPort Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port augustaPort Augusta
# sept-ilesSept-Iles
# Processing Record 340 | sept-ilesSept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sept-ilesSept-Iles
# ust-barguzinUst-Barguzin
# Processing Record 341 | ust-barguzinUst-Barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ust-barguzinUst-Barguzin
# karrathaKarratha
# Processing Record 342 | karrathaKarratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=karrathaKarratha
# nouakchottNouakchott
# Processing Record 343 | nouakchottNouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nouakchottNouakchott
# gravdalGravdal
# Processing Record 344 | gravdalGravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gravdalGravdal
# sidrolandiaSidrolandia
# Processing Record 345 | sidrolandiaSidrolandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sidrolandiaSidrolandia
# kurumochKurumoch
# Processing Record 346 | kurumochKurumoch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kurumochKurumoch
# waingapuWaingapu
# Processing Record 347 | waingapuWaingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=waingapuWaingapu
# Oops! <class 'KeyError'> occured.
# ojinagaOjinaga
# Processing Record 348 | ojinagaOjinaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ojinagaOjinaga
# conakryConakry
# Processing Record 349 | conakryConakry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=conakryConakry
# fort saint jamesFort Saint James
# Processing Record 350 | fort saint jamesFort Saint James
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fort saint jamesFort Saint James
# rochaRocha
# Processing Record 351 | rochaRocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rochaRocha
# yiduYidu
# Processing Record 352 | yiduYidu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yiduYidu
# ayaviriAyaviri
# Processing Record 353 | ayaviriAyaviri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ayaviriAyaviri
# hasakiHasaki
# Processing Record 354 | hasakiHasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hasakiHasaki
# torbayTorbay
# Processing Record 355 | torbayTorbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=torbayTorbay
# Oops! <class 'KeyError'> occured.
# fayaFaya
# Processing Record 356 | fayaFaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fayaFaya
# oriximinaOriximina
# Processing Record 357 | oriximinaOriximina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=oriximinaOriximina
# harnosandHarnosand
# Processing Record 358 | harnosandHarnosand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=harnosandHarnosand
# saint-georgesSaint-Georges
# Processing Record 359 | saint-georgesSaint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint-georgesSaint-Georges
# tucupitaTucupita
# Processing Record 360 | tucupitaTucupita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tucupitaTucupita
# tourosTouros
# Processing Record 361 | tourosTouros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tourosTouros
# hithadhooHithadhoo
# Processing Record 362 | hithadhooHithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hithadhooHithadhoo
# Oops! <class 'KeyError'> occured.
# bridlingtonBridlington
# Processing Record 363 | bridlingtonBridlington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bridlingtonBridlington
# Oops! <class 'KeyError'> occured.
# sebinkarahisarSebinkarahisar
# Processing Record 364 | sebinkarahisarSebinkarahisar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sebinkarahisarSebinkarahisar
# taksimoTaksimo
# Processing Record 365 | taksimoTaksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=taksimoTaksimo
# kamirKamir
# Processing Record 366 | kamirKamir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kamirKamir
# rawsonRawson
# Processing Record 367 | rawsonRawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rawsonRawson
# cabo san lucasCabo San Lucas
# Processing Record 368 | cabo san lucasCabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cabo san lucasCabo San Lucas
# huamboHuambo
# Processing Record 369 | huamboHuambo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=huamboHuambo
# ibraIbra
# Processing Record 370 | ibraIbra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ibraIbra
# Oops! <class 'KeyError'> occured.
# half moon bayHalf Moon Bay
# Processing Record 371 | half moon bayHalf Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=half moon bayHalf Moon Bay
# cuiluanCuiluan
# Processing Record 372 | cuiluanCuiluan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cuiluanCuiluan
# chicamaChicama
# Processing Record 373 | chicamaChicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chicamaChicama
# bualaBuala
# Processing Record 374 | bualaBuala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bualaBuala
# gryazovetsGryazovets
# Processing Record 375 | gryazovetsGryazovets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gryazovetsGryazovets
# cap malheureuxCap Malheureux
# Processing Record 376 | cap malheureuxCap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cap malheureuxCap Malheureux
# oranjemundOranjemund
# Processing Record 377 | oranjemundOranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=oranjemundOranjemund
# gushikawaGushikawa
# Processing Record 378 | gushikawaGushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gushikawaGushikawa
# tanoutTanout
# Processing Record 379 | tanoutTanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tanoutTanout
# north battlefordNorth Battleford
# Processing Record 380 | north battlefordNorth Battleford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=north battlefordNorth Battleford
# whittleseaWhittlesea
# Processing Record 381 | whittleseaWhittlesea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=whittleseaWhittlesea
# xuchengXucheng
# Processing Record 382 | xuchengXucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=xuchengXucheng
# saldanhaSaldanha
# Processing Record 383 | saldanhaSaldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saldanhaSaldanha
# santiago de caoSantiago de Cao
# Processing Record 384 | santiago de caoSantiago de Cao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=santiago de caoSantiago de Cao
# wukariWukari
# Processing Record 385 | wukariWukari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=wukariWukari
# meulabohMeulaboh
# Processing Record 386 | meulabohMeulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=meulabohMeulaboh
